# %% [markdown]
# # File for quick check of biotron data logger information

# %% [markdown]
# ##Import components

# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##Bring data in to Pandas dataframe

# %%
BiotronEnvironmentals=pd.read_csv('C:\GitHubRepos\BiotronEnvAnalysis\BiotronWheat.dat', #specify file path for data to read in
                         parse_dates=True, #tell the function to parse date columns to datetime formats
                         skiprows = [0,2,3,4], #leave out rows 1, 3 and 4 which have redundant information
                         index_col = 0, #Use the first column, which is Date, as an index
                         )
BiotronDailysMeans=BiotronEnvironmentals.resample('D', how='mean')

# %%
BiotronEnvironmentals.shape
# Out:
# (10289, 32)

# %% [markdown]
# ##Check rows and columns look ok

# %%
BiotronEnvironmentals.axes
# Out:
# [<class 'pandas.tseries.index.DatetimeIndex'>
#  [2014-07-29 17:11:00, ..., 2015-02-07 11:30:00]
#  Length: 10289, Freq: None, Timezone: None,
#  Index([u'RECORD', u'BattV_Avg', u'PTemp_C_Avg', u'WP_Avg(1)', u'WP_Avg(2)', u'WP_Avg(3)', u'WP_Avg(4)', u'MeanWP_Avg', u'DeltaT_C_Avg(1)', u'DeltaT_C_Avg(2)', u'DeltaT_C_Avg(3)', u'DeltaT_C_Avg(4)', u'Irrigations_Avg', u'Irrigations2_Avg', u'TT_C_Avg(1)', u'SBT_C_Avg(1)', u'TTmV_Avg(1)', u'TT_C_Avg(2)', u'SBT_C_Avg(2)', u'TTmV_Avg(2)', u'TT_C_Avg(3)', u'SBT_C_Avg(3)', u'TTmV_Avg(3)', u'PotTemp_Avg(1)', u'PotTemp_Avg(2)', u'PotTemp_Avg(3)', u'PotTemp_Avg(4)', u'PotTemp_Avg(5)', u'PotTemp_Avg(6)', u'PotTemp_Avg(7)', u'PotTemp_Avg(8)', u'PotTemp_Avg(9)'], dtype='object')]

# %% [markdown]
# ##Extract pot water data into data frame for the period we want to look at

# %%
from datetime import timedelta #Import function needed for doing date deltas 
EndDate = BiotronEnvironmentals.index.max(axis=0)  #Set end of series as most recent date in file
EndDateString = EndDate.strftime("%Y-%m-%d")  #Turn this to a string
PlotDuration = 1                            #Set the duration that you want to graph for
StartDate = EndDate - timedelta(weeks=PlotDuration)       #Set start date the specified duration before the end date 
StartDateString = StartDate.strftime("%Y-%m-%d")           #Turn that into a string
PotWater = BiotronEnvironmentals.ix[StartDateString:EndDateString,                     #create the dateframe for the specified period 
                                    [X for X in BiotronEnvironmentals if 'WP' in X]]   #inserting only the colunms containing water potential data

# %% [markdown]
# ##Graph pot water content signals

# %%
PotWater
# Out:
#                      WP_Avg(1)  WP_Avg(2)  WP_Avg(3)  WP_Avg(4)  MeanWP_Avg
# TIMESTAMP
# 2015-01-31 00:00:00      2.255      2.533      3.327      2.025       2.535
# 2015-01-31 00:30:00      2.293      2.554      3.355      2.025       2.557
# 2015-01-31 01:00:00      2.294      2.641      3.355      2.025       2.579
# 2015-01-31 01:30:00      2.275      2.685      3.438      2.042       2.610
# 2015-01-31 02:00:00      2.310      2.387      3.100      2.075       2.468
# 2015-01-31 02:30:00      2.304      2.380      3.032      2.053       2.442
# 2015-01-31 03:00:00      2.300      2.375      2.976      2.050       2.425
# 2015-01-31 03:30:00      2.278      2.353      2.996      2.031       2.414
# 2015-01-31 04:00:00      2.275      2.351      3.042      2.029       2.424
# 2015-01-31 04:30:00      2.273      2.388      3.117      2.028       2.451
# 2015-01-31 05:00:00      2.291      2.508      3.167      2.027       2.498
# 2015-01-31 05:30:00      2.271      2.633      3.298      2.026       2.557
# 2015-01-31 06:00:00      2.289      2.834      3.407      2.025       2.639
# 2015-01-31 06:30:00      2.251      2.291      2.918      2.008       2.367
# 2015-01-31 07:00:00      2.269      2.290      2.942      2.024       2.381
# 2015-01-31 07:30:00      2.269      2.309      2.942      2.007       2.382
# 2015-01-31 08:00:00      2.268      2.328      3.040      2.024       2.415
# 2015-01-31 08:30:00      2.231      2.385      3.140      2.007       2.441
# 2015-01-31 09:00:00      2.249      2.505      3.218      2.023       2.499
# 2015-01-31 09:30:00      2.267      2.719      3.379      2.023       2.597
# 2015-01-31 10:00:00      2.324      2.951      3.549      2.023       2.712
# 2015-01-31 10:30:00      2.267      2.290      2.942      2.007       2.376
# 2015-01-31 11:00:00      2.267      2.308      2.942      1.990       2.377
# 2015-01-31 11:30:00      2.267      2.308      2.966      1.990       2.383
# 2015-01-31 12:00:00      2.230      2.308      3.040      2.007       2.396
# 2015-01-31 12:30:00      2.267      2.425      3.166      1.990       2.462
# 2015-01-31 13:00:00      2.267      2.547      3.298      1.990       2.526
# 2015-01-31 13:30:00      2.304      2.742      3.407      2.007       2.615
# 2015-01-31 14:00:00      2.249      2.308      2.895      2.023       2.369
# 2015-01-31 14:30:00      2.267      2.309      2.919      1.990       2.371
# ...                        ...        ...        ...        ...         ...
# 2015-02-06 21:00:00      2.293      2.332      2.965      1.991       2.395
# 2015-02-06 21:30:00      2.294      2.333      2.991      2.009       2.406
# 2015-02-06 22:00:00      2.294      2.333      2.966      1.992       2.397
# 2015-02-06 22:30:00      2.295      2.372      2.966      1.993       2.407
# 2015-02-06 23:00:00      2.334      2.353      3.016      2.010       2.428
# 2015-02-06 23:30:00      2.315      2.353      2.991      2.010       2.417
# 2015-02-07 00:00:00      2.296      2.373      2.991      2.010       2.417
# 2015-02-07 00:30:00      2.315      2.393      3.016      2.010       2.433
# 2015-02-07 01:00:00      2.296      2.413      3.041      2.010       2.440
# 2015-02-07 01:30:00      2.354      2.473      3.117      2.010       2.489
# 2015-02-07 02:00:00      2.371      2.553      3.317      2.042       2.571
# 2015-02-07 02:30:00      2.425      2.653      3.322      2.056       2.614
# 2015-02-07 03:00:00      2.322      2.359      2.953      2.019       2.413
# 2015-02-07 03:30:00      2.319      2.356      2.948      2.000       2.406
# 2015-02-07 04:00:00      2.317      2.393      2.970      1.998       2.420
# 2015-02-07 04:30:00      2.316      2.451      3.068      2.014       2.462
# 2015-02-07 05:00:00      2.314      2.511      3.247      2.030       2.525
# 2015-02-07 05:30:00      2.410      2.680      3.354      2.012       2.614
# 2015-02-07 06:00:00      2.312      2.312      2.896      1.995       2.379
# 2015-02-07 06:30:00      2.293      2.331      2.919      2.011       2.388
# 2015-02-07 07:00:00      2.292      2.389      3.016      1.994       2.423
# 2015-02-07 07:30:00      2.311      2.509      3.167      1.994       2.495
# 2015-02-07 08:00:00      2.368      2.635      3.326      1.977       2.577
# 2015-02-07 08:30:00      2.508      2.883      3.493      1.994       2.719
# 2015-02-07 09:00:00      2.291      2.311      2.991      1.977       2.393
# 2015-02-07 09:30:00      2.272      2.311      3.065      1.977       2.406
# 2015-02-07 10:00:00      2.310      2.427      3.246      1.993       2.494
# 2015-02-07 10:30:00      2.329      2.570      3.353      1.993       2.561
# 2015-02-07 11:00:00      2.426      2.767      3.550      1.977       2.680
# 2015-02-07 11:30:00      2.272      2.273      2.943      1.977       2.366
#
# [360 rows x 5 columns]

# %%
plt.figure(figsize=(14, 14));
plt.title('Pot Moisture');
plt.plot(PotWater.index, PotWater);
plt.ylim(1.5,5);
plt.xlabel('Date');
plt.ylabel('Water Unit');
plt.legend(PotWater, loc='best')

# %% [markdown]
# ###Set up dataframes for temperature graphs

# %%
from datetime import timedelta #Import function needed for doing date deltas 
EndDate = BiotronEnvironmentals.index.max(axis=0)  #Set end of series as most recent date in file
EndDateString = EndDate.strftime("%Y-%m-%d")  #Turn this to a string
PlotDuration = 1                           #Set the duration that you want to graph for
StartDate = EndDate - timedelta(weeks=PlotDuration)       #Set start date the specified duration before the end date 
StartDateString = StartDate.strftime("%Y-%m-%d")           #Turn that into a string
PotTemps = BiotronEnvironmentals.ix[StartDateString:EndDateString,                     #create the dateframe for the specified period 
                                    [X for X in BiotronEnvironmentals if 'PotTemp' in X]]   #inserting only the colunms containing water potential data
SurfaceTemps = BiotronEnvironmentals.ix[StartDateString:EndDateString,                     #create the dateframe for the specified period 
                                    [X for X in BiotronEnvironmentals if 'TT_C' in X] ] 
Temps = pd.concat([SurfaceTemps, PotTemps],axis=1)  #JoinPotTemp and SurgaceTemp dataframes together

# %%
Temps.axes
# Out:
# [<class 'pandas.tseries.index.DatetimeIndex'>
#  [2015-01-31 00:00:00, ..., 2015-02-07 11:30:00]
#  Length: 360, Freq: 30T, Timezone: None,
#  Index([u'TT_C_Avg(1)', u'TT_C_Avg(2)', u'TT_C_Avg(3)', u'PotTemp_Avg(1)', u'PotTemp_Avg(2)', u'PotTemp_Avg(3)', u'PotTemp_Avg(4)', u'PotTemp_Avg(5)', u'PotTemp_Avg(6)', u'PotTemp_Avg(7)', u'PotTemp_Avg(8)', u'PotTemp_Avg(9)'], dtype='object')]

# %%
Temps.shape
# Out:
# (360, 12)

# %% [markdown]
# ##Draw graph of 30 min data

# %%
Temps.plot(figsize=(18,10),color=('r','y','y','b','g','b','g','g','b','b','b'))
plt.ylim(18,40);  
#plt.xlim(StartDate,EndDate)
plt.title('Pot temperatures');
plt.xlabel('Date');
plt.ylabel('Temperature');
plt.legend(loc='best')

# %%
PotTemps.plot(figsize=(18,10))
plt.ylim(18,40);
#plt.xlim(StartDate,EndDate)
plt.title('Pot temperatures');
plt.xlabel('Date');
plt.ylabel('Temperature');
plt.legend(loc='best')

# %% [markdown]
# ##Draw graph of daily mean temperatures

# %%
TempsDaily = Temps.resample('D', how='mean');
TempsDaily.ix[:,:11].plot(figsize=(18,10),color=('r','y','y','b','g','b','g','g','b','b','b'))
plt.ylim(18,30);
#plt.xlim(StartDate,EndDate)
plt.title('Pot temperatures');
plt.xlabel('Date');
plt.ylabel('Temperature');
plt.legend(loc='best')

# %%
# %matplotlib inline
BiotronEnvironmentals[['Irrigations_Avg', 'Irrigations2_Avg']].plot(legend=True, figsize=(14, 14));

# %%
SurfaceTemps.plot(figsize=(18,10),color=('r','y','y','b','g','b','g','g','b','b','b'))
plt.ylim(18,40);  
#plt.xlim(StartDate,EndDate)
plt.title('Pot temperatures');
plt.xlabel('Date');
plt.ylabel('Temperature');
plt.legend(loc='best')
